# %%
import requests
import pandas
from bs4 import BeautifulSoup

# %%
# initial input
account = '106010'
password = 'G122117609'
session = requests.session()
chracter_choose = 'cloud' # could choose "cloud" or "yourself"
ticket_type = 'handling'
search_column = 'disp_seq'
query_string = ''
max_count = None

# %%
chracters = {
    'cloud': '20',
    'yourself': account,
}

# %%
def login_with_given_session(account, password, session):
    post_url = 'http://202.3.168.17:8080/login_check.jsp'
    post_data = {
        'sess_id': account,
        'sess_password': password,
        'dfForm': 'login.jsp',
    }
    http_response = session.post(url=post_url, data=post_data)
    return http_response

# %%
login_with_given_session(account=account, password=password, session=session)
# Out:
# <Response [200]>

# %%
def search_on_dashboard_terminal(session, character, search_column, query_string, max_count):
    post_url = 'http://202.3.168.17:8080/Disp/DashBoard_Terminal.jsp?action=search'
    post_data = {
        'recordCount': max_count,
        'searchColumn': search_column,
        'searchCondition': query_string,
        'doSearch': 'Search',
        'character': character,
    }
    http_response = session.post(url=post_url, data=post_data)
    return http_response

# %%
search_http_response = search_on_dashboard_terminal(
    session=session,
    character=chracters[chracter_choose],
    search_column=search_column,
    query_string=query_string,
    max_count=max_count
)

# %%
def get_dataframe_list_by_reading_html(html):
    return pandas.read_html(html)

# %%
ticket_tables = get_dataframe_list_by_reading_html(search_http_response.text)

# %%
# take the part we want as a dictionary
ticket_tables = {
    'preordered': ticket_tables[2],
    'assigned': ticket_tables[3],
    'handling': ticket_tables[4],
    'finished': ticket_tables[5],
    'special': ticket_tables[6],
}

# %%
def let_the_first_row_be_column_title(dataframe):
    new_dataframe = dataframe[1:]
    new_dataframe.columns = dataframe.iloc[0]
    return new_dataframe

# %%
for key, value in ticket_tables.items():
    ticket_tables[key] = let_the_first_row_be_column_title(value)

# %%
def get_ticket_file_url_with_given_ticket_number(ticket_number, session):
    post_url = 'http://202.3.168.17:8080/Disp/DashBoard_Terminal_Detail.jsp'
    post_data = {
        'seq_no': ticket_number,
    }
    response = session.post(url=post_url, data=post_data)
    soup = BeautifulSoup(response.text, 'lxml')
    tag_set = soup.select('body > table > tr:nth-child(2) > td > fieldset > table > tr:nth-child(1) > td > ol > li > input[type=button]:nth-child(1)')
    if len(tag_set) == 1:
        tag = tag_set[0]
    else:
        tag = None
    if tag:
        url = tag['onclick'].split(',')[0].split('"')[1]
    else:
        url = ''
    return url

# %%
urls = [ get_ticket_file_url_with_given_ticket_number(ticket, session) for ticket in list(ticket_tables['handling']['單號'])]

# %%
ticket_tables['handling'].assign(建置單檔案=urls)
# Out:
# 0                     單號                  客戶名稱                       協銷客戶名稱  \
# 1   202003240627 (Delay)            格威傳媒股份有限公司                          NaN
# 2           202004290985          中信房屋仲介股份有限公司                          NaN
# 3           202004270937            中國旺旺控股有限公司                          NaN
# 4           202004220892            海博資訊股份有限公司                          NaN
# 5           202004210873              傑思網擎有限公司                          NaN
# 6           202004210872            鈊象電子股份有限公司                          NaN
# 7           202004210871  OLYMPIC STAR LIMITED                          NaN
# 8           202004170860              發現資訊有限公司                          NaN
# 9           202004150826           TY solution                          NaN
# 10          202004100791                雲一有限公司           [建置單: ] [案管:IGS-3]
# 11          202004100790              棋苓股份有限公司                          NaN
# 12          202004100789        歐米英泰智慧服務股份有限公司                          NaN
# 13          202004090778            次元科技股份有限公司  [建置單: ] [案管:DDos Testing-C]
# 14          202004090777            次元科技股份有限公司  [建置單: ] [案管:DDos Testing-B]
# 15          202004090776            次元科技股份有限公司  [建置單: ] [案管:DDos Testing-A]
# 16          202004080774              喬創科技有限公司                          NaN
# 17          202004070759  Pragmatic Software S                          NaN
# 18          202004060743                    新黨                          NaN
# 19          202003300699  財團法人國家實驗研究院國家高速網路與計算                          NaN
# 20          202003300697            是方電訊股份有限公司                          NaN
# 21          202003300696            是方電訊股份有限公司                          NaN
# 22          202003300695            是方電訊股份有限公司                          NaN
# 23          202003240629            因萬整合行銷有限公司                          NaN
# 24          202003230612              新領科技有限公司                          NaN
# 25          202003190600            是方電訊股份有限公司                          NaN
# 26          202003110519            海博資訊股份有限公司                          NaN
# 27          202003110515            是方電訊股份有限公司                          NaN
# 28          202003040454          網擎資訊軟體股份有限公司                          NaN
# 29          202003040451            華電聯網股份有限公司                          NaN
# 30          202002150304            是方電訊股份有限公司                          NaN
# 31          202002060225            是方電訊股份有限公司                          NaN
# 32          201911042590            聖普科技股份有限公司                          NaN
# 33          201911042589          先啟資訊系統股份有限公司                          NaN
#
# 0       類別   專案   流程                                              建置單檔案
# 1   新增/測試單  李瑞賢  處理中
# 2   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 3   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 4   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 5   異動/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 6   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 7   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 8   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 9   新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 10  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 11  新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 12  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 13  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 14  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 15  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 16  退租/一般單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 17  退租/一般單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 18  退租/一般單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 19  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 20  新增/內工單  葉柏輝  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 21  新增/內工單   龔哲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 22  新增/內工單   龔哲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 23  新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 24  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 25  新增/內工單   龔哲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 26  新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 27  新增/內工單   龔哲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 28  新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 29  新增/一般單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 30  新增/內工單   龔哲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 31  新增/內工單  葉柏輝  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 32  新增/測試單  李忠憲  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...
# 33  新增/測試單  李瑞賢  處理中  http://202.3.168.75:8080/build_report.jsp?tw_f...

# %%
def get_ticket_detail_with_given_ticket_number(session, chracter, ticket_number):
    post_url = 'http://202.3.168.17:8080/Disp/retriveDetail.jsp'
    post_data = {
        'method': 'get_Disp_DetailCons',
        'Disp_Cons_Seq': chracter,
        'Disp_Grp_Seq': chracter,
        'Disp_Seq': ticket_number,
    }
    http_response = session.post(url=post_url, data=post_data)
    return http_response

# %%
df_list = []
for ticket_number in list(ticket_tables[ticket_type]['單號']):
    ticket_detail_response = get_ticket_detail_with_given_ticket_number(session=session, chracter=chracters[chracter_choose], ticket_number=ticket_number)
    df_ticket_detail = get_dataframe_list_by_reading_html(ticket_detail_response.text)[0]
    df_ticket_detail = let_the_first_row_be_column_title(df_ticket_detail)
    df_ticket_detail = df_ticket_detail.assign(單號=ticket_number)
    df_list += [df_ticket_detail]

# %%
df_left = pandas.concat(df_list)
df_right = ticket_tables[ticket_type]
db_joined = pandas.merge(df_left, df_right, on='單號', how='outer', suffixes=('', '-細項'))

# %%
db_joined
# Out:
# 0      工務名稱 裝機地址    工務同仁                 轉派時間   流程   工期  \
# 0   是方應用雲服務  NaN  雲端-李忠穎  2020-04-30 16:03:34  處理中    3
# 1        其他  NaN  雲端-楊家瑋  2020-04-27 17:42:27  處理中    3
# 2      VM服務  NaN  雲端-楊家瑋  2020-04-22 18:11:22  處理中    2
# 3      VM服務  NaN  雲端-林敬智  2020-04-21 11:30:40  處理中    3
# 4   VM服務-頻寬  NaN  雲端-林敬智  2020-04-21 11:30:45  處理中    9
# ..      ...  ...     ...                  ...  ...  ...
# 69       其他  NaN  雲端-楊家瑋  2019-11-05 13:43:59  處理中    3
# 70  VM服務-頻寬  NaN  雲端-楊家瑋  2019-11-05 13:43:52  處理中    9
# 71     VM服務  NaN  雲端-楊家瑋  2019-11-05 13:43:46  處理中    3
# 72       其他  NaN  雲端-楊家瑋  2019-11-05 13:44:05  處理中    3
# 73      NaN  NaN     NaN                  NaN  NaN  NaN
#
# 0                                            工務起訖日 待竣時間                    單號  \
# 0                       標:2020/04/30~2020/05/05預:~  NaN          202004290985
# 1   標:2020/04/28~2020/04/30預:2020/05/15~2020/05/16  NaN          202004270937
# 2   標:2020/04/23~2020/04/24預:2020/05/31~2020/06/01  NaN          202004220892
# 3   標:2020/04/22~2020/04/24預:2020/06/17~2020/06/17  NaN          202004210873
# 4   標:2020/04/22~2020/05/05預:2020/06/17~2020/06/17  NaN          202004210873
# ..                                             ...  ...                   ...
# 69  標:2019/11/06~2019/11/08預:2020/06/30~2020/07/01  NaN          201911042589
# 70  標:2019/11/06~2019/11/18預:2020/06/30~2020/07/01  NaN          201911042589
# 71  標:2019/11/06~2019/11/08預:2020/06/30~2020/07/01  NaN          201911042589
# 72  標:2019/11/06~2019/11/08預:2020/06/30~2020/07/01  NaN          201911042589
# 73                                             NaN  NaN  202003240627 (Delay)
#
# 0           客戶名稱 協銷客戶名稱      類別   專案 流程-細項
# 0   中信房屋仲介股份有限公司    NaN  新增/測試單  李瑞賢   處理中
# 1     中國旺旺控股有限公司    NaN  新增/測試單  李瑞賢   處理中
# 2     海博資訊股份有限公司    NaN  新增/測試單  李瑞賢   處理中
# 3       傑思網擎有限公司    NaN  異動/測試單  李瑞賢   處理中
# 4       傑思網擎有限公司    NaN  異動/測試單  李瑞賢   處理中
# ..           ...    ...     ...  ...   ...
# 69  先啟資訊系統股份有限公司    NaN  新增/測試單  李瑞賢   處理中
# 70  先啟資訊系統股份有限公司    NaN  新增/測試單  李瑞賢   處理中
# 71  先啟資訊系統股份有限公司    NaN  新增/測試單  李瑞賢   處理中
# 72  先啟資訊系統股份有限公司    NaN  新增/測試單  李瑞賢   處理中
# 73    格威傳媒股份有限公司    NaN  新增/測試單  李瑞賢   處理中
#
# [74 rows x 14 columns]
